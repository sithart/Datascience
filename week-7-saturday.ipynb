# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb://MongoDB:yI6PriD2HdpmmlmV@cluster0-shard-00-00.rhqfc.mongodb.net:27017,cluster0-shard-00-01.rhqfc.mongodb.net:27017,cluster0-shard-00-02.rhqfc.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-p6vupm-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client['test']

# %%
import quandl

# %%
data=quandl.get("BSE/Sensex", start_date="2019-01-01")

# %%
data
# Out:
#                 Open      High       Low     Close
# Date
# 2019-01-01  36161.80  36284.04  35888.62  36254.57
# 2019-01-02  36198.13  36236.70  35734.01  35891.52
# 2019-01-03  35934.50  35999.66  35475.57  35513.71
# 2019-01-04  35590.79  35744.20  35382.08  35695.10
# 2019-01-07  35971.18  36076.95  35809.23  35850.16
# ...              ...       ...       ...       ...
# 2022-04-18  57338.58  57420.80  56842.39  57166.74
# 2022-04-19  57381.77  57464.08  56009.07  56463.15
# 2022-04-20  56741.43  57216.51  56521.33  57037.50
# 2022-04-21  57458.60  57991.53  57311.86  57911.68
# 2022-04-22  57531.95  57689.86  57134.72  57197.15
#
# [820 rows x 4 columns]

# %%
# First convert DF to Dict for mongoDB Insertion
data_dict = data.to_dict("records")
data_dict
# Out:
# [{'Date': Timestamp('2019-01-01 00:00:00'),
#   'Open': 36161.8,
#   'High': 36284.04,
#   'Low': 35888.62,
#   'Close': 36254.57},
#  {'Date': Timestamp('2019-01-02 00:00:00'),
#   'Open': 36198.13,
#   'High': 36236.7,
#   'Low': 35734.01,
#   'Close': 35891.52},
#  {'Date': Timestamp('2019-01-03 00:00:00'),
#   'Open': 35934.5,
#   'High': 35999.66,
#   'Low': 35475.57,
#   'Close': 35513.71},
#  {'Date': Timestamp('2019-01-04 00:00:00'),
#   'Open': 35590.79,
#   'High': 35744.2,
#   'Low': 35382.08,
#   'Close': 35695.1},
#  {'Date': Timestamp('2019-01-07 00:00:00'),
#   'Open': 35971.18,
#   'High': 36076.95,
#   'Low': 35809.23,
#   'Close': 35850.16},
#  {'Date': Timestamp('2019-01-08 00:00:00'),
#   'Open': 35964.62,
#   'High': 36037.35,
#   'Low': 35753.95,
#   'Close': 35980.93},
#  {'Date': Timestamp('2019-01-09 00:00:00'),
#   'Open': 36181.37,
#   'High': 36250.54,
#   'Low': 35863.29,
#   'Close': 36212.91},
#  {'Date': Timestamp('2019-01-10 00:00:00'),
# ...

# %%
# In our dict output Index - "Date" was omitted. you can check with output dictionary
data.reset_index(inplace=True) # It included  the Date index in the data Frame
data_dict = data.to_dict("records")
data_dict
# Out:
# [{'index': 0,
#   'Date': Timestamp('2019-01-01 00:00:00'),
#   'Open': 36161.8,
#   'High': 36284.04,
#   'Low': 35888.62,
#   'Close': 36254.57},
#  {'index': 1,
#   'Date': Timestamp('2019-01-02 00:00:00'),
#   'Open': 36198.13,
#   'High': 36236.7,
#   'Low': 35734.01,
#   'Close': 35891.52},
#  {'index': 2,
#   'Date': Timestamp('2019-01-03 00:00:00'),
#   'Open': 35934.5,
#   'High': 35999.66,
#   'Low': 35475.57,
#   'Close': 35513.71},
#  {'index': 3,
#   'Date': Timestamp('2019-01-04 00:00:00'),
#   'Open': 35590.79,
#   'High': 35744.2,
#   'Low': 35382.08,
#   'Close': 35695.1},
#  {'index': 4,
#   'Date': Timestamp('2019-01-07 00:00:00'),
#   'Open': 35971.18,
#   'High': 36076.95,
#   'Low': 35809.23,
#   'Close': 35850.16},
#  {'index': 5,
#   'Date': Timestamp('2019-01-08 00:00:00'),
#   'Open': 35964.62,
#   'High': 36037.35,
#   'Low': 35753.95,
#   'Close': 35980.93},
#  {'index': 6,
#   'Date': Timestamp('2019-01-09 00:00:00'),
#   'Open': 36181.37,
# ...

# %%
col = db["BSE"]

# %%
col
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-00.rhqfc.mongodb.net:27017', 'cluster0-shard-00-02.rhqfc.mongodb.net:27017', 'cluster0-shard-00-01.rhqfc.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='atlas-p6vupm-shard-0', authsource='admin', retrywrites=True, w='majority', tls=True), 'test'), 'BSE')

# %%
col.insert_many(data_dict)

# %%
col1 = db["SENSEX"]

# %%
# If we need to insert the Bulk data this is not the good practice
for i in data_dict:
    col1.insert_one(i)

# %%
pip install vega-datasets
# Out:
# ...
#      ------------------------------------ 210.8/210.8 KB 713.8 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from vega_datasets import data

# %%
dir(data) #Available methods
# Out:
# ['7zip',
#  'airports',
#  'annual_precip',
#  'anscombe',
#  'barley',
#  'birdstrikes',
#  'budget',
#  'budgets',
#  'burtin',
#  'cars',
#  'climate',
#  'co2_concentration',
#  'countries',
#  'crimea',
#  'disasters',
#  'driving',
#  'earthquakes',
#  'ffox',
#  'flare',
#  'flare_dependencies',
#  'flights_10k',
#  'flights_200k',
#  'flights_20k',
#  'flights_2k',
#  'flights_3m',
#  'flights_5k',
#  'flights_airport',
#  'gapminder',
#  'gapminder_health_income',
#  'gimp',
#  'github',
#  'graticule',
#  'income',
#  'iowa_electricity',
#  'iris',
#  'jobs',
#  'la_riots',
#  'londonBoroughs',
#  'londonCentroids',
#  'londonTubeLines',
#  'lookup_groups',
#  'lookup_people',
#  'miserables',
#  'monarchs',
#  'movies',
#  'normal_2d',
#  'obesity',
#  'ohlc',
#  'points',
#  'population',
#  'population_engineers_hurricanes',
#  'seattle_temps',
#  'seattle_weather',
#  'sf_temps',
#  'sp500',
#  'stocks',
#  'udistrict',
#  'unemployment',
# ...

# %%
# You can connect anything from above Vega datasets

# %%
df = data.crimea()

# %%
df
# Out:
#          date  wounds  other  disease
# 0  1854-04-01       0    110      110
# 1  1854-05-01       0     95      105
# 2  1854-06-01       0     40       95
# 3  1854-07-01       0    140      520
# 4  1854-08-01      20    150      800
# 5  1854-09-01     220    230      740
# 6  1854-10-01     305    310      600
# 7  1854-11-01     480    290      820
# 8  1854-12-01     295    310     1100
# 9  1855-01-01     230    460     1440
# 10 1855-02-01     180    520     1270
# 11 1855-03-01     155    350      935
# 12 1855-04-01     195    195      560
# 13 1855-05-01     180    155      550
# 14 1855-06-01     330    130      650
# 15 1855-07-01     260    130      430
# 16 1855-08-01     290    110      490
# 17 1855-09-01     355    100      290
# 18 1855-10-01     135     95      245
# 19 1855-11-01     100    140      325
# 20 1855-12-01      40    120      215
# 21 1856-01-01       0    160      160
# 22 1856-02-01       0    100      100
# 23 1856-03-01       0    125       90

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     24 non-null     datetime64[ns]
#  1   wounds   24 non-null     int64
#  2   other    24 non-null     int64
#  3   disease  24 non-null     int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 896.0 bytes

# %%
import json

# %%
file = open(r"C:\Users\sitha\Downloads\anscombe.json")

# %%
data = json.load(file)

# %%
data
# Out:
# [{'Series': 'I', 'X': 10.0, 'Y': 8.04},
#  {'Series': 'I', 'X': 8.0, 'Y': 6.95},
#  {'Series': 'I', 'X': 13.0, 'Y': 7.58},
#  {'Series': 'I', 'X': 9.0, 'Y': 8.81},
#  {'Series': 'I', 'X': 11.0, 'Y': 8.33},
#  {'Series': 'I', 'X': 14.0, 'Y': 9.96},
#  {'Series': 'I', 'X': 6.0, 'Y': 7.24},
#  {'Series': 'I', 'X': 4.0, 'Y': 4.26},
#  {'Series': 'I', 'X': 12.0, 'Y': 10.84},
#  {'Series': 'I', 'X': 7.0, 'Y': 4.81},
#  {'Series': 'I', 'X': 5.0, 'Y': 5.68},
#  {'Series': 'II', 'X': 10.0, 'Y': 9.14},
#  {'Series': 'II', 'X': 8.0, 'Y': 8.14},
#  {'Series': 'II', 'X': 13.0, 'Y': 8.74},
#  {'Series': 'II', 'X': 9.0, 'Y': 8.77},
#  {'Series': 'II', 'X': 11.0, 'Y': 9.26},
#  {'Series': 'II', 'X': 14.0, 'Y': 8.1},
#  {'Series': 'II', 'X': 6.0, 'Y': 6.13},
#  {'Series': 'II', 'X': 4.0, 'Y': 3.1},
#  {'Series': 'II', 'X': 12.0, 'Y': 9.13},
#  {'Series': 'II', 'X': 7.0, 'Y': 7.26},
#  {'Series': 'II', 'X': 5.0, 'Y': 4.74},
#  {'Series': 'III', 'X': 10.0, 'Y': 7.46},
# ...

# %%
col_new = db["anscombe"]

# %%
col_new.insert_many(data)

# %%
col_new_1 = db["anscombe_series_II_only"]

# %%
for i in data:
    if i["Series"] == "II":
        print(i)
        col_new_1.insert_one(i)
# Out:
# {'Series': 'II', 'X': 10.0, 'Y': 9.14, '_id': ObjectId('6263b4e65b50f17214343dc0')}
# {'Series': 'II', 'X': 8.0, 'Y': 8.14, '_id': ObjectId('6263b4e65b50f17214343dc1')}
# {'Series': 'II', 'X': 13.0, 'Y': 8.74, '_id': ObjectId('6263b4e65b50f17214343dc2')}
# {'Series': 'II', 'X': 9.0, 'Y': 8.77, '_id': ObjectId('6263b4e65b50f17214343dc3')}
# {'Series': 'II', 'X': 11.0, 'Y': 9.26, '_id': ObjectId('6263b4e65b50f17214343dc4')}
# {'Series': 'II', 'X': 14.0, 'Y': 8.1, '_id': ObjectId('6263b4e65b50f17214343dc5')}
# {'Series': 'II', 'X': 6.0, 'Y': 6.13, '_id': ObjectId('6263b4e65b50f17214343dc6')}
# {'Series': 'II', 'X': 4.0, 'Y': 3.1, '_id': ObjectId('6263b4e65b50f17214343dc7')}
# {'Series': 'II', 'X': 12.0, 'Y': 9.13, '_id': ObjectId('6263b4e65b50f17214343dc8')}
# {'Series': 'II', 'X': 7.0, 'Y': 7.26, '_id': ObjectId('6263b4e65b50f17214343dc9')}
# {'Series': 'II', 'X': 5.0, 'Y': 4.74, '_id': ObjectId('6263b4e65b50f17214343dca')}

# %%
# Interview Question
# 16 MB size for Embedding data
# For one document we just go 100 Nested

col_new_2 = db['sample2']

# %%
col_new_2.insert_one({'name':['sitharthan','priyanga','Heera'],'food':{'dosa':'south','roti':'north'},'age':'27'})

# %%
# Tomorrow 24-04-2022
# we will deep dive into pandas
